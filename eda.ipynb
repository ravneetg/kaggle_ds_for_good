# %%
import pandas as pd

import os

# %%
home_dir = "./data"

for path, subdirs, files in os.walk(home_dir):
    for name in files:
        print os.path.join(path, name)
# Out:
# ./data/data-science-for-good.zip
# ./data/ACS_variable_descriptions.csv
# ./data/Dept_37-00027/37-00027_UOF-P_2014-2016_prepped.csv
# ./data/Dept_37-00027/37-00027_Shapefiles/APD_DIST.shp
# ./data/Dept_37-00027/37-00027_Shapefiles/APD_DIST.dbf
# ./data/Dept_37-00027/37-00027_Shapefiles/APD_DIST.sbx
# ./data/Dept_37-00027/37-00027_Shapefiles/APD_DIST.shx
# ./data/Dept_37-00027/37-00027_Shapefiles/APD_DIST.sbn
# ./data/Dept_37-00027/37-00027_ACS_data/_DS_Store
# ./data/Dept_37-00027/37-00027_ACS_data/37-00027_ACS_owner-occupied-housing/ACS_16_5YR_S2502_with_ann.csv
# ./data/Dept_37-00027/37-00027_ACS_data/37-00027_ACS_owner-occupied-housing/ACS_16_5YR_S2502_metadata.csv
# ./data/Dept_37-00027/37-00027_ACS_data/37-00027_ACS_education-attainment-over-25/ACS_16_5YR_B15003_metadata.csv
# ./data/Dept_37-00027/37-00027_ACS_data/37-00027_ACS_education-attainment-over-25/ACS_16_5YR_B15003_with_ann.csv
# ...
